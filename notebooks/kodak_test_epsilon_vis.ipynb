# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
from h_test_IQM.datasets.numpy_loaders import kodak_loader
from h_test_IQM.metrics import IQMs
from h_test_IQM.distortions import noise_sphere
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
kodak_ims = kodak_loader()
im = kodak_ims[6]
distort = noise_sphere.epislon_noise(epsilon=40)
noisey = distort(im)
br = IQMs.BRISQUE()

# %%
# show images side by side in matplotlib subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].imshow(im)
ax[0].set_title(f'original- BRISQUE: {br(im)}')
ax[1].imshow(noisey)
ax[1].set_title(f'noisy- BRISQUE: {br(noisey)}')
plt.imshow(im)
