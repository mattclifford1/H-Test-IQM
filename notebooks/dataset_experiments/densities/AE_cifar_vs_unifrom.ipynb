# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from h_test_IQM.pipeline import get_scores
from scipy.stats import entropy

# %%
outputs = get_scores(
    dataset_target='CIFAR_10',
    # dataset_test='CIFAR_10',
    # dataset_test='KODAK',
    dataset_test='UNIFORM',
    transform_target=None,
    transform_test=None,
    scorer='entropy-2-mse',
    test=['KL', 'plot_hist'],
    device='cuda',
    batch_size=32,
    dev=False,
    shift_seed_test=1,
    dataset_proportion_target=0.2,
    dataset_proportion_test=0.2,
    )
# Out:
# Pipeline:
#         target_dataset:   CIFAR_10
#         test_dataset:     UNIFORM
#         transform_target: None
#         transform_test:   None
#         scorer:           entropy-2-mse
#         test type:        ['KL', 'plot_hist']
#
#     Extras:
#         device:     cuda
#         batch size: 32
#         dev mode:   False
# scoring:   0%|          | 0/150 [00:00<?, ?it/s]
# num target samples: 4800
# num test samples: 4800
#
# KL divergence: 4.707540048047841
