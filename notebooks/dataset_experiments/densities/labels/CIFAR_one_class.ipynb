# %%
# %load_ext autoreload
# %autoreload 2
from h_test_IQM.pipeline import get_scores
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = 'CIFAR_10'
target_labels = list(range(10))
test_labels = [1]
dataset_proportion_test = 1  
dataset_proportion_target = dataset_proportion_test*(len(test_labels)/len(target_labels))
dataset_proportion_target = 1
outputs = get_scores(
    dataset_target=dataset,
    dataset_test=dataset,
    target_labels=target_labels,
    test_labels=test_labels,
    dataset_proportion_target=dataset_proportion_target,
    dataset_proportion_test=dataset_proportion_test,
    scorer='entropy-2-mse',
    test=['KL', 'plot_hist'],
    device='cuda',
    dev=False,
    seed=0,
    )
# Out:
# Pipeline:
#         target_dataset:   CIFAR_10
#         test_dataset:     CIFAR_10
#         transform_target: None
#         transform_test:   None
#         scorer:           entropy-2-mse
#         test type:        ['KL', 'plot_hist']
#
#     Extras:
#         device:     cuda
#         batch size: 32
#         dev mode:   False
# num target samples: 24000
# num test samples: 2400
#
# KL divergence: 0.13641852119518055
