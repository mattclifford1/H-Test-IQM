# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from h_test_IQM.pipeline.multiple import run_multiple_pipelines
from h_test_IQM.pipeline.main import plot_hist, samples_to_pdf
from tqdm import tqdm

# %%
# parameters for each test to set up
run1 = {'dataset': 'Caltech256', 
        'data_labels': 'all', 
        'dataset_proportion': 0.4, 
        'noise': 'gaussian_noise',
        'test': 'KL',
        'dev': False,   # If True, the code will run on very small data size
        'runs': 100,
        }

# things to change for the test against
run2 = run1.copy()
run2['dataset'] = 'Caltech101'
run2['dataset_proportion'] = max(1, run1['dataset_proportion']*2)

# %%
# run the tests for each configuration
test1, test2 = run_multiple_pipelines([run1, run2])
# Out:
# ...
# Caltech256:   9%|▉         | 9/100 [06:00<1:00:48, 40.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # run the tests for each configuration
# ----> 2 test1, test2 = run_multiple_pipelines([run1, run2])
#
# File ~/projects/H-Test-IQM/h_test_IQM/pipeline/multiple.py:17, in run_multiple_pipelines(pipeline_list, cache_data)
#      15     run['name'] = run['dataset']
#      16 for i in tqdm(range(run['runs']), desc=run['name']):
# ---> 17     outputs = get_scores(
#      18         dataset_target=run['dataset'],
#      19         dataset_test=run['dataset'],
#      20         target_labels=run['data_labels'],
#      21         test_labels=run['data_labels'],
#      22         transform_test=run['noise'],
#      23         scorer='entropy-2-mse',
#      24         test=run['test'],
#      25         dev=run['dev'],
# ...

# %%
# plot the results (difference of differneces)
test1 = np.array(test1)
test2 = np.array(test2)
# NB: samples_to_pdf returns dist1 built from its FIRST argument. This used to be
# called as (test2, test1) while the labels stayed (run1, run2), which swapped every
# legend in this family of figures -- see FINDINGS.md 3.2.
dist1, dist2, bins1, bins2 = samples_to_pdf(
    test1, test2, num_bins=50)
plot_hist(dist1, bins1, name=run1['name'])
plot_hist(dist2, bins2, name=run2['name'])
plt.xlabel('KL divergence')
plt.ylabel('Density')
plt.legend()
plt.show()
